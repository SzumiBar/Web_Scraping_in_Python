# %% [markdown]
# # Simple Web Scraping in Python
# ### My first attempt at trying to gather static HTML content from Pracuj.pl and RocketJobs employment websites and present it in tabular format. Searches include keywords 'Junior Data' and 'Data Analyst'.

# %%
from IPython.display import display, HTML
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %% [markdown]
# ## Scraping content from RocketJobs

# %%
rocket_jobs_dict = {
    'Job':[],
    'Employer':[],
    'Localization':[],
    'Keywords':[]
}

html_txt = requests.get('https://rocketjobs.pl/wszystkie-lokalizacje/bi-data?orderBy=DESC&sortBy=newest&keyword=data+analyst').text
soup = BeautifulSoup(html_txt, 'html.parser')
offers = soup.find_all('div', class_='css-1tksz28')

for offer in offers:
    rocket_jobs_dict['Job'].append(offer.h2.text)
    rocket_jobs_dict['Employer'].append(offer.find('div', class_='css-jx23jo').text)
    city = offer.find('div', class_='css-1wao8p8').text
    rocket_jobs_dict['Localization'].append(re.search('^[A-Za-zÓóŃńŁłŹźĆćŚśŻżü]+', city).group(0))
    rocket_jobs_dict['Keywords'].append([keyword.text for keyword in offer.find_all('div', class_='css-12973y2')])

rocket_jobs_df = pd.DataFrame(rocket_jobs_dict)
rocket_jobs_df.insert(0, 'Site', 'RocketJobs')

# %% [markdown]
# ## Scraping content from Pracuj.pl

# %%
pracuj_pl_dict = {
    'Job':[],
    'Employer':[],
    'Localization':[],
    'Keywords':[]
}

pp_urls = ('https://www.pracuj.pl/praca/junior%20data;kw',
           'https://www.pracuj.pl/praca/junior%20data;kw?pn=2',
           'https://www.pracuj.pl/praca/junior%20data;kw?pn=3',
           'https://www.pracuj.pl/praca/junior%20data;kw?pn=4')

def pp_fill(urls):
    for url in urls:
        html_txt = requests.get(url).text
        soup = BeautifulSoup(html_txt, 'html.parser')
        offers = soup.find_all('div', class_='tiles_c1lzjarj')

        for offer in offers:
            pracuj_pl_dict['Job'].append(offer.h2.text)
            pracuj_pl_dict['Employer'].append(offer.h4.text)
            pracuj_pl_dict['Localization'].append(offer.h5.text)
            keywords = offer.ul.find_all('li', class_='mobile-hidden tiles_iwlrcdk')
            pracuj_pl_dict['Keywords'].append([keyword.text for keyword in keywords])

pp_fill(pp_urls)
pracuj_pl_df = pd.DataFrame(pracuj_pl_dict)
pracuj_pl_df.insert(0, 'Site', 'Pracuj.pl')

# %% [markdown]
# ## Display of scraped data

# %%
job_offers = pd.concat((rocket_jobs_df, pracuj_pl_df), ignore_index=True)
job_offers.loc[(True if len(loc) > 50 else False for loc in job_offers['Localization']),
               'Localization'] = 'Cała Polska'

display(HTML(job_offers.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Site</th>
#       <th>Job</th>
#       <th>Employer</th>
#       <th>Localization</th>
#       <th>Keywords</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>RocketJobs</td>
#       <td>Junior Data Analyst 📈</td>
#       <td>PROXI.CLOUD SP. Z O.O.</td>
#       <td>Poznań</td>
#       <td>[SQL, data-driven marketing, Analiza Danych, New]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>RocketJobs</td>
#       <td>Product Data Analyst</td>
#       <td>STS</td>
#       <td>Katowice</td>
#       <td>[SQL, BigQuery, Google Tag Manager, New]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>RocketJobs</td>
#       <td>Data Engineer</td>
#       <td>Profitroom</td>
#       <td>Poznań</td>
#       <td>[Zdalnie, PySpark, Python, Data modeling, New]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>RocketJobs</td>
#       <td>BI Analyst</td>
#       <td>Lite e-Commerce</td>
#       <td>Poznań</td>
#       <td>[SQL, PowerBI, data analyst]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>RocketJobs</td>
#       <td>Lider Zespołu Analiz</td>
#       <td>Moliera2 S.A.</td>
#       <td>Warszawa</td>
#       <td>[Snowflake, Big Query, machine learning]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>RocketJobs</td>
#       <td>Data Governance Specialist - EDM (Hybrid)</td>
#       <td>Northvolt</td>
#       <td>Gdańsk</td>
#       <td>[Process Improvement, process implementation, communication skills]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>RocketJobs</td>
#       <td>Data Analyst w marce Mohito</td>
#       <td>LPP S.A.</td>
#       <td>Kraków</td>
#       <td>[MS Excel, Angielski, Google Analytics, New]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>RocketJobs</td>
#       <td>Młodszy Analityk Internetowy</td>
#       <td>CANAL+ Polska S.A.</td>
#       <td>Warszawa</td>
#       <td>[data analyst, analiza, e-commerce, New]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>RocketJobs</td>
#       <td>Senior Business Analyst</td>
#       <td>Motorola Solutions</td>
#       <td>Kraków</td>
#       <td>[Angielski, data analyst, New]</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>RocketJobs</td>
#       <td>Business Data Analyst</td>
#       <td>RocketJobs.pl</td>
#       <td>Gdańsk</td>
#       <td>[Angielski, SQL, PowerBI, New]</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>RocketJobs</td>
#       <td>Business Data Analyst</td>
#       <td>Just Join IT</td>
#       <td>Warszawa</td>
#       <td>[SQL, PowerBI, DAX, New]</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>RocketJobs</td>
#       <td>Analityk danych internetowych</td>
#       <td>COMARCH S.A</td>
#       <td>Kraków</td>
#       <td>[ecommerce, data analyst, e-commerce]</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>RocketJobs</td>
#       <td>Junior Data Analyst</td>
#       <td>IT CONNECT</td>
#       <td>Warszawa</td>
#       <td>[SQL, data analysys]</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>RocketJobs</td>
#       <td>Analytics Engineer</td>
#       <td>VOLT</td>
#       <td>Krakow</td>
#       <td>[DBT, PowerBI, tableau]</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>RocketJobs</td>
#       <td>Data Analyst (Digital Media)</td>
#       <td>Performance Media Poland</td>
#       <td>Warszawa</td>
#       <td>[SQL, API, Google Ads]</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>RocketJobs</td>
#       <td>Senior Big Data Analyst</td>
#       <td>Simplicity Recruitment</td>
#       <td>Warszawa</td>
#       <td>[Big data, Analytics, SQL]</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>RocketJobs</td>
#       <td>Head of Data Analytics</td>
#       <td>Printify</td>
#       <td>Warszawa</td>
#       <td>[Zdalnie, Team Leadership, English, Python]</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>RocketJobs</td>
#       <td>Analytics Manager - Cluster Lead</td>
#       <td>Kitopi</td>
#       <td>Kraków</td>
#       <td>[Zdalnie, Analytics, stakeholder management, ELT, New]</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>RocketJobs</td>
#       <td>Data Analyst - Data Intelligence (relocation)</td>
#       <td>trivago</td>
#       <td>Düsseldorf</td>
#       <td>[R, Python, BigQuery]</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>RocketJobs</td>
#       <td>Data &amp; Reporting Senior Developer</td>
#       <td>ALTEN Polska</td>
#       <td>Kraków</td>
#       <td>[SQL]</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>RocketJobs</td>
#       <td>Data Analyst</td>
#       <td>RITS Professional Services</td>
#       <td>Łódź</td>
#       <td>[BI, SAP]</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>RocketJobs</td>
#       <td>Service Manager</td>
#       <td>Technicus</td>
#       <td>Warszawa</td>
#       <td>[Jira Service Management, ITIL, PowerBI]</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>RocketJobs</td>
#       <td>Senior Data Engineer with Python</td>
#       <td>Objectivity - part of Accenture</td>
#       <td>Oleśnica</td>
#       <td>[Zdalnie, Databricks]</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>RocketJobs</td>
#       <td>Senior Data Engineer with Python</td>
#       <td>Objectivity - part of Accenture</td>
#       <td>Kalisz</td>
#       <td>[Zdalnie, Databricks]</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>RocketJobs</td>
#       <td>Staż - Junior Data Analyst</td>
#       <td>Wirtualna Polska Media S.A.</td>
#       <td>Gdańsk</td>
#       <td>[SQL, Bash, linux]</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>RocketJobs</td>
#       <td>Big Data Engineer</td>
#       <td>Experis Manpower Group</td>
#       <td>Warszawa</td>
#       <td>[Zdalnie, ETL, Scala, Python]</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>RocketJobs</td>
#       <td>Big Data Developer (Python, Scala, Spark)</td>
#       <td>ITDS</td>
#       <td>Łódź</td>
#       <td>[Zdalnie, Python, Apache Kafka, Apache Spark]</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>RocketJobs</td>
#       <td>Data Analyst (GCP)</td>
#       <td>ITDS</td>
#       <td>Kraków</td>
#       <td>[T-SQL, Python, MS Excel]</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>RocketJobs</td>
#       <td>Data Analyst (with Python)</td>
#       <td>Airly</td>
#       <td>Kraków</td>
#       <td>[numpy, InfluxDB, SQL]</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>RocketJobs</td>
#       <td>Data Analyst</td>
#       <td>Silky Coders</td>
#       <td>Gdańsk</td>
#       <td>[excel, ms office]</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>RocketJobs</td>
#       <td>Senior Data Analyst</td>
#       <td>Silky Coders</td>
#       <td>Gdynia</td>
#       <td>[excel, ms office]</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>RocketJobs</td>
#       <td>Data Analyst</td>
#       <td>Limango Polska</td>
#       <td>Poznań</td>
#       <td>[Zdalnie, tableau, PowerBI, SQL]</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>RocketJobs</td>
#       <td>Power Platform Developer</td>
#       <td>JellyTech Sp. z o.o.</td>
#       <td>Gdynia</td>
#       <td>[ms sql dw, SQL, sharepoint]</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>RocketJobs</td>
#       <td>Junior Data Analyst</td>
#       <td>DevsData LLC</td>
#       <td>Katowice</td>
#       <td>[Zdalnie, SQL, Snowflake, Data]</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>RocketJobs</td>
#       <td>Analityk Biznesowy</td>
#       <td>BISAR S.A.</td>
#       <td>Pruszcz</td>
#       <td>[Zdalnie, SQL, MS Excel, analiza, New]</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>RocketJobs</td>
#       <td>Staż działu Analiz Biznesowych</td>
#       <td>General Logistics Systems</td>
#       <td>Poznań</td>
#       <td>[Zdalnie, MS Excel, analiza, data analyst, New]</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>RocketJobs</td>
#       <td>IT Performance Reporting Analyst II</td>
#       <td>Herbalife Nutrition</td>
#       <td>Kraków</td>
#       <td>[analiza, data analyst, Power Bi, New]</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>RocketJobs</td>
#       <td>Analityk Danych</td>
#       <td>Balton Sp. z o.o.</td>
#       <td>Warszawa</td>
#       <td>[SQL, Angielski, data analyst, New]</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <
